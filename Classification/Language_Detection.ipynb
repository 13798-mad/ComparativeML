# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,accuracy_score

# %%
data=pd.read_csv("language_data.csv")
data.head(5)
# Out:
#             text language
# 0  我正在阅读的书是关于1的。  Chinese
# 1         今天是2度。  Chinese
# 2     你听说过3的新闻吗？  Chinese
# 3         今天是4度。  Chinese
# 4     我最喜欢的爱好是5。  Chinese

# %%
plt.figure(figsize=(12,5))
sns.countplot(x="language",data=data,palette="Blues")
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/km/41xdld515hq8qyv7nx3qq6n80000gn/T/ipykernel_35060/475134438.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="language",data=data,palette="Blues")

# %% [markdown]
# # Feature Engineering

# %%
x=data["text"]
y=data["language"]
tf=TfidfVectorizer(max_features=5000)
x=tf.fit_transform(x)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # Model

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)

# %% [markdown]
# # Results

# %%
print("Accuracy",accuracy_score(y_test,y_pred)*100)
print("Classification Report",classification_report(y_test,y_pred))
# Out:
# Accuracy 100.0
# Classification Report               precision    recall  f1-score   support
#
#      Chinese       1.00      1.00      1.00       180
#      Finnish       1.00      1.00      1.00       169
#       French       1.00      1.00      1.00       215
#        Greek       1.00      1.00      1.00       219
#     Gujarati       1.00      1.00      1.00       210
#        Hindi       1.00      1.00      1.00       196
#   Indonesian       1.00      1.00      1.00       206
#      Italian       1.00      1.00      1.00       202
#       Korean       1.00      1.00      1.00       208
#        Malay       1.00      1.00      1.00       225
#      Marathi       1.00      1.00      1.00       194
#       Nepali       1.00      1.00      1.00       186
#      Persian       1.00      1.00      1.00       205
#       Polish       1.00      1.00      1.00       203
#   Portuguese       1.00      1.00      1.00       173
#      Russian       1.00      1.00      1.00       214
#      Spanish       1.00      1.00      1.00       198
#      Swedish       1.00      1.00      1.00       193
#      Tagalog       1.00      1.00      1.00       195
#        Tamil       1.00      1.00      1.00       194
#       Telugu       1.00      1.00      1.00       201
#         Urdu       1.00      1.00      1.00       214
#
#     accuracy                           1.00      4400
#    macro avg       1.00      1.00      1.00      4400
# weighted avg       1.00      1.00      1.00      4400
